# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
import matplotlib.cbook as cbook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
numsample = 5000
numdim = 14
m = np.zeros((numdim,numsample))
m[1,4]
# Out:
# 0.0

# %%
m.shape
for i in range(numsample):
    m[6,i] = np.random.normal(0.0,1.5)/2
    m[9,i] = -m[6,i]+np.random.normal(0.0,0.05)
    m[1,i] = np.cos(2*m[6,i])+np.random.normal(0.0,0.2)
    m[12,i] = np.sin(2*m[6,i])+np.random.normal(0.0,0.2)
    
plt.plot(m[6,:],m[9,:],'x')

# %%
mean = [2*3.14, 2*3.14]
cov = [[1.5, 0.75], [0.75, 1.5]]
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.hold(True)
mean = [-2*3.14, -2*3.14]
cov = [[1.5, -0.75], [-0.75, 1.5]]
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')

# %%
numsample = 5000;
numdim = 14;

np.random.uniform(-np.pi,np.pi,numsample) 

t = np.random.uniform(-np.pi,np.pi,numsample)+np.random.normal(0,pi/2,numsample)
# %n = normrnd(0,1,1,numsample)
x1 = np.cos(t)+ np.random.normal(0.0,0.25,numsample)
x12 = np.sin(t) + np.random.normal(0.0,0.25,numsample)
x6 = t/2+ np.random.normal(0.0,0.1,numsample)
x9 = -t/2+ np.random.normal(0.0,0.1,numsample)

#m = [x1',x6',x9',x12'];

#csvwrite('data_gen.csv',m);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-ba1159a88422> in <module>()
#       4 np.random.uniform(-np.pi,np.pi,numsample)
#       5
# ----> 6 t = np.random.uniform(-np.pi,np.pi,numsample)+np.random.normal(0,pi/2,1,numsample)
#       7 get_ipython().magic(u'n = normrnd(0,1,1,numsample)')
#       8 x1 = np.cos(t)+ np.random.normal(0.0,0.25,numsample)
#
# mtrand.pyx in mtrand.RandomState.normal (numpy/random/mtrand/mtrand.c:14445)()
#
# TypeError: normal() takes at most 3 positional arguments (4 given)
